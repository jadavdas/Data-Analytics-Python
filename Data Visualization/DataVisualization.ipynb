# %%
import matplotlib.pyplot as plt
import math
import numpy as np

# %% [markdown]
# # Simple Plot

# %%
t = np.arange(0, 2, 0.01)
f = 2
omega = 2*math.pi*f
u = np.sin(omega*t)
v = np.sin(omega*t + 2*math.pi/3)
w = np.sin(omega*t - 2*math.pi/3)
plt.rcParams["figure.figsize"] = (20,3)
plt.plot(t,u,'b*', t, v,'g^', t, w, 'ys')
plt.title('Three Phase Current', fontsize = 20, fontname = 'Times New Roman')
plt.xlabel('Time (s)', color ='gray')
plt.ylabel('Current (A)', color = 'gray')
plt.grid(True)
plt.legend(['U','V','W'], loc = 1)

# %%
plt.rcParams["figure.figsize"] = (20,3)
plt.plot(t,u,'b--', t, v,'g', t, w, 'y-', linewidth = 2.0)
plt.title('Three Phase Current', fontsize = 20, fontname = 'Times New Roman')
plt.xlabel('Time (s)', color ='gray')
plt.ylabel('Current (A)', color = 'gray')
plt.grid(True)
plt.legend(['U','V','W'], loc = 1)

# %% [markdown]
# # Subplots

# %%
plt.rcParams["figure.figsize"] = (10,5)
plt.subplot(311)
plt.plot(t,u,'b-',linewidth = 2)
plt.xlabel('Time (s)', color ='gray')
plt.ylabel('Current (A)', color = 'gray')
plt.grid(True)
plt.legend(['U'], loc = 1)
plt.subplot(312)
plt.plot(t,v,'g', linewidth = 2)
plt.xlabel('Time (s)', color ='gray')
plt.ylabel('Current (A)', color = 'gray')
plt.grid(True)
plt.legend(['V'], loc = 1)
plt.subplot(313)
plt.plot(t,w,'y', linewidth = 2)
plt.xlabel('Time (s)', color ='gray')
plt.ylabel('Current (A)', color = 'gray')
plt.grid(True)
plt.legend(['W'], loc = 1)

# %%
plt.rcParams["figure.figsize"] = (20,5)
plt.subplot(131)
plt.plot(t,u,'b-',linewidth = 2)
plt.xlabel('Time (s)', color ='gray')
plt.ylabel('Current (A)', color = 'gray')
plt.grid(True)
plt.legend(['U'], loc = 1)
plt.subplot(132)
plt.plot(t,v,'g', linewidth = 2)
plt.xlabel('Time (s)', color ='gray')
plt.ylabel('Current (A)', color = 'gray')
plt.grid(True)
plt.legend(['V'], loc = 1)
plt.subplot(133)
plt.plot(t,w,'y', linewidth = 2)
plt.xlabel('Time (s)', color ='gray')
plt.ylabel('Current (A)', color = 'gray')
plt.grid(True)
plt.legend(['W'], loc = 1)

# %% [markdown]
# # Adding Test

# %%
plt.axis([0,5,0,20])
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.xlabel('Counting')
plt.ylabel('Square Values')
plt.text(1, 1.5, str('First'))
plt.text(2, 4.5, 'Second')
plt.text(3, 9.5, str('Third'))
plt.text(4, 16.5, 'Fourth')
plt.text(1.1, 12, r'$y = x^2$', fontsize = 20, bbox = {'facecolor':'yellow', 'alpha':0.2})
plt.grid()
plt.savefig('myfig.png')

# %% [markdown]
# # Handling Dates

# %%
import datetime
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
months = mdates.MonthLocator()
days = mdates.DayLocator()
timeFmt = mdates.DateFormatter('%Y-%m')
events = [datetime.date(2015,1,23), datetime.date(2015,1,28), datetime.date(2015,2,3), datetime.date(2015,2,21), 
          datetime.date(2015,3,15), datetime.date(2015,3,24), datetime.date(2015,4,18), datetime.date(2015,4,24) ]
readings = [12, 22, 25, 20, 18, 15, 17, 14]
fig, ax = plt.subplots()
plt.plot(events, readings)
ax.xaxis.set_major_locator(months)
ax.xaxis.set_major_formatter(timeFmt)
ax.xaxis.set_minor_locator(days)

# %% [markdown]
# # Line Charts

# %%
x = np.arange(-2*np.pi, 2*np.pi, 0.01)
y = np.sin(3*x)/x
y2 = np.sin(2*x)/x
y3 = np.sin(x)/x
plt.plot(x,y,color='b')
plt.plot(x,y2,color='r')
plt.plot(x,y3,color='g')
plt.xticks([-2*np.pi, -np.pi, 0, np.pi, 2*np.pi], [r'$-2\pi$', r'$-\pi$', r'$0$', r'$+\pi$', r'$+2\pi$'])
plt.yticks([-1, 0, +1, +2, +3], [r'$-1$',r'0$',r'$+1$',r'$+2$',r'$+3$'])
plt.annotate(r'$\lim_{x\to 0}\frac{\sin(x)}{x}= 1$',  xy = [0,1], xycoords = 'data', xytext=[30, 30], fontsize=16, 
             textcoords='offset points', arrowprops=dict(arrowstyle="->", connectionstyle="arc3, rad=0.2"))
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

# %%
import pandas as pd
data = {'series1':[1,3,4,3,5], 'series2':[2,4,5,2,4],'series3':[3,2,3,1,3]}
df = pd.DataFrame(data)
x = np.arange(5)
plt.axis([0,5,0,7])
plt.plot(x,df)
plt.legend(data, loc=2)

# %% [markdown]
# # Histograms

# %%
pop = np.random.randint(0, 100, 100)
n, bins, patches = plt.hist(pop, bins=20)

# %% [markdown]
# # Bar Charts

# %%
index = [0,1,2,3,4]
values = [5,7,3,4,6]
plt.bar(index,values)
plt.xticks(index, ['A','B','C','D','E'])
# Out:
# ([<matplotlib.axis.XTick at 0x212c12b2b50>,
# ...
#  [Text(0, 0, 'A'),
#   Text(1, 0, 'B'),
#   Text(2, 0, 'C'),
#   Text(3, 0, 'D'),
#   Text(4, 0, 'E')])

# %%
index = [0,1,2,3,4]
values = [5,7,3,4,6]
std = [0.8,1,0.4,0.9,1.3]
plt.bar(index,values,yerr=std,error_kw={'ecolor':'0.1','capsize':6},alpha=0.7,label='First')
plt.xticks(index, ['A','B','C','D','E'])
plt.legend(loc=2)

# %%
plt.barh(index,values,xerr=std,error_kw={'ecolor':'0.1','capsize':6},alpha=0.7,label='First')
plt.xticks(index, ['A','B','C','D','E'])
plt.legend(loc=5)

# %%
index = np.arange(5)
values1 = [5,7,3,4,6]
values2 = [6,6,4,5,7]
values3 = [5,6,5,4,6]
bw = 0.3
plt.axis([0,5,0,8])
plt.title('A Multiseries Bar Chart', fontsize=20)
plt.bar(index,values1,bw,color='b')
plt.bar(index+bw,values2,bw,color='g')
plt.bar(index+2*bw,values3,bw,color='r')
plt.xticks(index+1.5*bw,['A','B','C','D','E'])
# Out:
# ([<matplotlib.axis.XTick at 0x17660d90970>,
# ...
#  [Text(0.44999999999999996, 0, 'A'),
#   Text(1.45, 0, 'B'),
#   Text(2.45, 0, 'C'),
#   Text(3.45, 0, 'D'),
#   Text(4.45, 0, 'E')])

# %%
index = np.arange(5)
values1 = [5,7,3,4,6]
values2 = [6,6,4,5,7]
values3 = [5,6,5,4,6]
bw = 0.3
plt.axis([0,8,0,5])
plt.title('A Multiseries Horizontal Bar Chart', fontsize=20)
plt.barh(index,values1,bw,color='b')
plt.barh(index+bw,values2,bw,color='g')
plt.barh(index+2*bw,values3,bw,color='r')
plt.xticks(index+0.4,['A','B','C','D','E'])
# Out:
# ([<matplotlib.axis.XTick at 0x1766154ce50>,
# ...
#  [Text(0.4, 0, 'A'),
#   Text(1.4, 0, 'B'),
#   Text(2.4, 0, 'C'),
#   Text(3.4, 0, 'D'),
#   Text(4.4, 0, 'E')])

# %%
import pandas as pd
data = {'series1':[1,3,4,3,5], 'series2':[2,4,5,2,4],'series3':[3,2,3,1,3]}
df = pd.DataFrame(data)
df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
series1 = np.array([3,4,5,3])
series2 = np.array([1,2,2,5])
series3 = np.array([2,3,3,4])
index = np.arange(4)
plt.axis([-0.5, 3.5, 0, 15])
plt.title('A Multiseries Stacked Bar Chart')
plt.bar(index, series1,color='r')
plt.bar(index,series2,color='b',bottom=series1)
plt.bar(index,series3,color='g',bottom=(series2+series1))
plt.xticks(index,['Jan18','Feb18','Mar18','Apr18'])
# Out:
# ([<matplotlib.axis.XTick at 0x176624fffd0>,
# ...
#  [Text(0, 0, 'Jan18'),
#   Text(1, 0, 'Feb18'),
#   Text(2, 0, 'Mar18'),
#   Text(3, 0, 'Apr18')])

# %%
series1 = np.array([3,4,5,3])
series2 = np.array([1,2,2,5])
series3 = np.array([2,3,3,4])
index = np.arange(4)
plt.axis([0, 15, -0.5, 3.5])
plt.title('A Multiseries Stacked Bar Chart')
plt.barh(index, series1,color='r')
plt.barh(index,series2,color='b',left=series1)
plt.barh(index,series3,color='g',left=(series2+series1))
plt.yticks(index,['Jan18','Feb18','Mar18','Apr18'])
# Out:
# ([<matplotlib.axis.YTick at 0x176637be670>,
# ...
#  [Text(0, 0, 'Jan18'),
#   Text(0, 1, 'Feb18'),
#   Text(0, 2, 'Mar18'),
#   Text(0, 3, 'Apr18')])

# %%
series1 = np.array([3,4,5,3])
series2 = np.array([1,2,2,5])
series3 = np.array([2,3,3,4])
index = np.arange(4)
plt.axis([0, 15, -0.5, 3.5])
plt.title('A Multiseries Stacked Bar Chart')
plt.barh(index, series1,color='w',hatch ='xx')
plt.barh(index,series2,color='w',hatch ='///',left=series1)
plt.barh(index,series3,color='w',hatch ='\\\\\\',left=(series2+series1))
plt.yticks(index,['Jan18','Feb18','Mar18','Apr18'])
# Out:
# ([<matplotlib.axis.YTick at 0x17663839430>,
# ...
#  [Text(0, 0, 'Jan18'),
#   Text(0, 1, 'Feb18'),
#   Text(0, 2, 'Mar18'),
#   Text(0, 3, 'Apr18')])

# %%
import pandas as pd
data = {'series1':[1,3,4,3,5], 'series2':[2,4,5,2,4],'series3':[3,2,3,1,3]}
df = pd.DataFrame(data)
df.plot(kind='bar',stacked=True)
# Out:
# <AxesSubplot:>

# %%
x0 = np.arange(8)
y1 = np.array([1,3,4,6,4,3,2,1])
y2 = np.array([1,2,5,4,3,3,2,1])
plt.ylim(-7,7)
plt.bar(x0,y1,0.9,facecolor='r')
plt.bar(x0,-y2,0.9,facecolor='b')
plt.xticks(())
plt.grid()
for x, y in zip(x0,y1):
    plt.text(x+0.4, y+0.05,'%d' %y, ha='center', va='bottom')
    
for x, y in zip(x0,y2):
    plt.text(x+0.4, -y-0.05, '%d' %y, ha='center', va='top')

# %% [markdown]
# # Pie Charts

# %%
labels = ['Nokia','Samsung','Apple','Lumia']
values = [10,30,45,15]
colors = ['yellow','green','red','blue']
plt.pie(values,labels=labels,colors=colors)
plt.axis('equal')
# Out:
# (-1.11637372803214,
#  1.1007797090739162,
#  -1.1163737124158366,
#  1.1007797083302826)

# %%
explode = [0.3,0,0,0]
plt.pie(values,labels=labels,colors=colors,explode=explode,startangle=180)
plt.axis('equal')
# Out:
# (-1.4003625034945653,
#  1.130639575385504,
#  -1.1007797083302826,
#  1.1163737124158366)

# %%
plt.pie(values,labels=labels,colors=colors,explode=explode,shadow=True, autopct='%1.1f%%',startangle=180)
plt.axis('equal')
# Out:
# (-1.4003625034945653,
#  1.130639575385504,
#  -1.1007797083302826,
#  1.1163737124158366)

# %%
data = {'series1':[1,3,4,3,5], 'series2':[2,4,5,2,4],'series3':[3,2,3,1,3]}
df = pd.DataFrame(data)
df['series1'].plot(kind='pie',figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='series1'>

# %% [markdown]
# # Contour Plots

# %%
dx = 0.01; dy = 0.01
x = np.arange(-2.0, 2.0, dx)
y = np.arange(-2.0, 2.0, dy)
X, Y = np.meshgrid(x,y)
def f(x,y):
    return (1-y**5 + x**5) * np.exp(-x**2 - y**2)
C = plt.contour(X,Y,f(X,Y),8,colors='black')
plt.contourf(X,Y,f(X,Y),8)
plt.clabel(C, inline=1, fontsize=10)
plt.colorbar()

# %% [markdown]
# # Polar Charts

# %%
N = 8
theta = np.arange(0.,2*np.pi,2*np.pi/N)
radii = np.array([4,7,5,3,1,5,6,7])
plt.axes([0.025,0.025,0.95, 0.95], polar = True)
colors = np.array(['#4bb2c5','#c5b47f','#EAA228','#579575','#839557','#958c12','#953579','#4b5de4'])
bars = plt.bar(theta,radii,width=(2*np.pi/N), bottom=0.0, color=colors)

# %%
N = 8
theta = np.arange(0.,2*np.pi,2*np.pi/N)
radii = np.array([4,7,5,3,1,5,6,7])
plt.axes([0.025,0.025,0.95, 0.95], polar = True)
colors = np.array(['lightgreen','darkred','navy','brown','violet','plum','yellow','darkgreen'])
bars = plt.bar(theta,radii,width=(2*np.pi/N), bottom=0.0, color=colors)

# %% [markdown]
# # 3D Surfaces

# %%
from matplotlib import cm
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
X = np.arange(-2,2,0.1)
Y = np.arange(-2,2,0.1)
X,Y = np.meshgrid(X,Y)
def f(x,y):
    return (1-y**5 + x**5) * np.exp(-x**2 - y**2)
surf = ax.plot_surface(X, Y, f(X,Y), cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
ax.view_init(elev=30,azim=125)

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
X, Y, Z = axes3d.get_test_data(0.05)
ax.plot_surface(X, Y, Z, rstride=8, cstride=8, alpha=0.3)
cset = ax.contour(X, Y, Z, zdir='z', offset=-100, cmap=cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='x', offset=-40, cmap=cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='y', offset=40, cmap=cm.coolwarm)

ax.set_xlabel('X')
ax.set_xlim(-40, 40)
ax.set_ylabel('Y')
ax.set_ylim(-40, 40)
ax.set_zlabel('Z')
ax.set_zlim(-100, 100)

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import numpy as np

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

# Make data.
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter('{x:.02f}')

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %% [markdown]
# # Scatter Plot

# %%
xs = np.random.randint(30,40,100)
ys = np.random.randint(20,30,100)
zs = np.random.randint(10,20,100)

xs2 = np.random.randint(50,60,100)
ys2 = np.random.randint(30,40,100)
zs2 = np.random.randint(50,70,100)

xs3 = np.random.randint(10,30,100)
ys3 = np.random.randint(40,50,100)
zs3 = np.random.randint(40,50,100)

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.scatter(xs,ys,zs)
ax.scatter(xs2,ys2,zs2,c='r',marker='^')
ax.scatter(xs3,ys3,zs3,c='g',marker='*')
ax.set_xlabel('X'); ax.set_ylabel('Y'); ax.set_zlabel('Z')
# Out:
# Text(0.5, 0, 'Z')

# %% [markdown]
# # 3D Bar Chart

# %%
import matplotlib.pyplot as plt
import numpy as np

#Fixing random state
np.random.seed(10)

colors = ['r', 'g', 'b', 'y']
yticks = [3, 2, 1, 0]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_yticks(yticks)

for c, k in zip(colors, yticks):
  #Generate the random data for the y=k 'layer'.
  xs = np.arange(20)
  ys = np.random.rand(20)

  #providing color to the series
  cs = [c] * len(xs)
  cs[0] = 'c'

  # Plot the 3D bar graph given by xs and ys 
  #on the plane y=k with 80% opacity.
  ax.bar(xs, ys, zs=k, zdir='y', 
            color=cs, alpha=0.8)

plt.show()

# %% [markdown]
# # Multi-Panel Plot

# %%
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.8,0.8])
inner_ax = fig.add_axes([0.6,0.6,0.25,0.25])
x1 = np.arange(10)
y1 = np.array([1,2,7,1,5,2,4,2,3,1])
x2 = np.arange(10)
y2 = np.array([1,3,4,5,4,5,2,6,4,3])
ax.plot(x1,y1)
inner_ax.plot(x2,y2)

# %%
gs = plt.GridSpec(3,3)
fig = plt.figure(figsize=(6,6))
x1 = np.arange(10)
y1 = np.array([1,2,7,1,5,2,4,2,3,1])
x2 = np.arange(10)
y2 = np.array([1,3,4,5,4,5,2,6,4,3])

s1 = fig.add_subplot(gs[1,:2])
s1.plot(x1,y1,'r')

s2 = fig.add_subplot(gs[0,:2])
s2.bar(x2,y2)

s3 = fig.add_subplot(gs[2,0])
s3.barh(x2,y2,color='g')

s4 = fig.add_subplot(gs[:2,2])
s4.plot(x1,y1,'k')

s5 = fig.add_subplot(gs[2,1:])
s5.plot(x1,y1,'r^',x2,y2,'yo')
